# %% [markdown]
# # 📈 02 - Parameter Calculation
# ## Calculating the 9 volcanic monitoring parameters

# %%
# Basic imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

print("📊 Parameter Calculation Notebook")
print("Calculate S, P, G, D, H, E, W, L, R indices")
