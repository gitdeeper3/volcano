# %% [markdown]
# # Lyapunov Analysis - Lyapunov Analysis
# ## Chaos theory and stability analysis

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

print("🌋 Lyapunov Analysis")
print("Chaos theory and stability analysis")
