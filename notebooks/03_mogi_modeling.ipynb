# %% [markdown]
# # Mogi Modeling - Mogi Modeling
# ## Physics-based deformation models

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

print("🌋 Mogi Modeling")
print("Physics-based deformation models")
