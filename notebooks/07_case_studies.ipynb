# %% [markdown]
# # Case Studies - Case Studies
# ## Historical eruption case studies

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

print("🌋 Case Studies")
print("Historical eruption case studies")
